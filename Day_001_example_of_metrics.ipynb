# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 網址：https://www.kaggle.com/c/two-sigma-financial-news/data
#
# 1. 你選的這組資料為何重要
# 每年投資人都因為巨大的股市波動而蒙受鉅額損失，本題目希望透過新聞來掌握股市動向
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 股市資料與新聞資料
#
# 3. 蒐集而來的資料型態為何
# float64
#
# 4. 這組資料想解決的問題如何評估
# 透過函數來評估與市場的差異以計算準確度

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
#
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 如何有效提升營收
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 司機的里程數
# 載客路徑
# 油價資訊
# 尖峰與離峰時段
# 3. 蒐集而來的資料型態為何?
# csv
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 解釋營收與各項變數的相關性

# %% [markdown]
# 作業3：
#
# 請點選檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#
# 資料夾結構建立規則提醒：ML100 > data資料夾 & ipynb檔
#
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.031
